# %% [markdown]
# ### Funcionamiento básico del módulo de la camara

# %%
# importamos el módulo de la camara
import sys
sys.path.append('../../')
from camera_module import CameraModule

# %%
# Eliminar el directorio con las imagenes
import shutil
directory = 'CameraModule_log'
shutil.rmtree(directory, ignore_errors=True)

# %% [markdown]
# A continuación se instancia la camara y se comienza a tomar fotografias

# %%
cam = CameraModule(capture_period=0.5)

cam.capturing = True

cam.capture()
# Out:
# Foto CameraModule_Log\000.jpg guardada.
#   Varianza: 4294.229871738847
#   Entropía: 5.2900309562683105
#   SSIM medio: None
#   Nivel de ruido: 9.979517353652533
# Advertencia: La imagen 0 podría estar desviada de la normalidad.
# Foto CameraModule_Log\001.jpg guardada.
#   Varianza: 4318.344207275221
#   Entropía: 5.2922539710998535
#   SSIM medio: None
#   Nivel de ruido: 9.968646229176024
# Advertencia: La imagen 1 podría estar desviada de la normalidad.
# Foto CameraModule_Log\002.jpg guardada.
#   Varianza: 4312.762146805658
#   Entropía: 5.291234016418457
#   SSIM medio: None
#   Nivel de ruido: 9.96322359033454
# Advertencia: La imagen 2 podría estar desviada de la normalidad.
# Foto CameraModule_Log\003.jpg guardada.
#   Varianza: 4324.565563800557
#   Entropía: 5.293231964111328
#   SSIM medio: None
#   Nivel de ruido: 9.966375586146555
# Advertencia: La imagen 3 podría estar desviada de la normalidad.
# Foto CameraModule_Log\004.jpg guardada.
# ...
